# %% [markdown]
# <a href="https://colab.research.google.com/github/AryanPatel-AI/Transcribe-/blob/main/transcribesentimentsecAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai-whisper
# !apt install ffmpeg
import whisper
from google.colab import files
from transformers import pipeline

modle = whisper.load_model('base')
uploaded = files.upload()
current_audio = list(uploaded.keys())[0]
result = modle.transcribe(current_audio)
transcribe = result['text']
print(transcribe)
sentiment_pipeline = pipeline('sentiment-analysis')
sentiment_text = sentiment_pipeline(transcribe)
print(sentiment_text)
